# %%
import pandas as pd

# %%
clients = pd.read_csv('../Data/cliente_tabla.csv')
clients.head()
# Out:
#    Cliente_ID                            NombreCliente
# 0           0                               SIN NOMBRE
# 1           1                         OXXO XINANTECATL
# 2           2                               SIN NOMBRE
# 3           3                                EL MORENO
# 4           4  SDN SER  DE ALIM  CUERPO SA CIA  DE INT

# %%
clients.sort_values(by='NombreCliente')
# Out:
#         Cliente_ID                            NombreCliente
# 245494      717837                                      007
# 586361     2378063                   056 THE AIRPORT MARKET
# 169147      434384                                       06
# 403611     1561951                                  0RLANDO
# 236980      676479                                    1 2 3
# 175993      459250                                    1 2 3
# 35912        90427                                    1 2 3
# 504682     2075276                               1 DE ABRIL
# 310273     1055376                           1 DE DICIEMBRE
# 237623      679382                               1 DE JULIO
# 307922     1044379                               1 DE MARZO
# 343683     1233640                               1 DE MARZO
# 934031     9632653                               1 DE MARZO
# 219097      601273                                1 DE MAYO
# 255651      771821                                1 DE MAYO
# ...
